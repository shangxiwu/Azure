# %% [markdown]
# # 印刷文字辨識服務操作

# %%
from azure.cognitiveservices.vision.computervision import ComputerVisionClient
# from azure.cognitiveservices.vision.computervision.models import TextOperationStatusCodes
from msrest.authentication import CognitiveServicesCredentials
import time
import json
import os
import sys
import requests
import time
# If you are using a Jupyter notebook, uncomment the following line.
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon
from PIL import Image
from io import BytesIO


# Set API key.
subscription_key = '390b0e8c9f8b43d9a21e896e74ae1c7b'
# Set endpoint.
endpoint = 'https://aien08cv01.cognitiveservices.azure.com/'
# Call API
computervision_client = ComputerVisionClient(endpoint, CognitiveServicesCredentials(subscription_key))

'''
Batch Read File, recognize printed text - remote
This example will extract printed text in an image, then print results, line by line.
This API call can also recognize handwriting (not shown).
'''
print("===== Batch Read File - remote =====")
# Get an image with printed text
text_recognition_url = endpoint + "/vision/v3.0/read/analyze"
remote_image_printed_text_url = "https://raw.githubusercontent.com/Azure-Samples/cognitive-services-sample-data-files/master/ComputerVision/Images/printed_text.jpg"

# Call API with URL and raw response (allows you to get the operation location)
recognize_printed_results = computervision_client.batch_read_file(remote_image_printed_text_url,  raw=True)

# Get the operation location (URL with an ID at the end) from the response
operation_location_remote = recognize_printed_results.headers["Operation-Location"]
# Grab the ID from the URL
operation_id = operation_location_remote.split("/")[-1]

# Call the "GET" API and wait for it to retrieve the results 
while True:
    get_printed_text_results = computervision_client.get_read_operation_result(operation_id)
    if get_printed_text_results.status not in ['NotStarted', 'Running']:
        break
    time.sleep(1)

# Print the detected text, line by line
if get_printed_text_results.status == TextOperationStatusCodes.succeeded:
    for text_result in get_printed_text_results.recognition_results:
        for line in text_result.lines:
            print(line.text)
            print(line.bounding_box)
print()
# Out:
# ===== Batch Read File - remote =====
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-1a47359faa3f> in <module>
#      34
#      35 # Call API with URL and raw response (allows you to get the operation location)
# ---> 36 recognize_printed_results = computervision_client.batch_read_file(remote_image_printed_text_url,  raw=True)
#      37
#      38 # Get the operation location (URL with an ID at the end) from the response
#
# AttributeError: 'ComputerVisionClient' object has no attribute 'batch_read_file'

# %%
import json
import os
import sys
import requests
import time
# If you are using a Jupyter notebook, uncomment the following line.
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon
from PIL import Image
from io import BytesIO

missing_env = False
# Add your Computer Vision subscription key and endpoint to your environment variables.
# if 'COMPUTER_VISION_ENDPOINT' in os.environ:
#    endpoint = os.environ['COMPUTER_VISION_ENDPOINT']
# else:
#     print("From Azure Cogntivie Service, retrieve your endpoint and subscription key.")
#     print("\nSet the COMPUTER_VISION_ENDPOINT environment variable, such as \"https://westus2.api.cognitive.microsoft.com\".\n")
#     missing_env = True
# 
# if 'COMPUTER_VISION_SUBSCRIPTION_KEY' in os.environ:
#     subscription_key = os.environ['COMPUTER_VISION_SUBSCRIPTION_KEY']
# else:
#     print("From Azure Cogntivie Service, retrieve your endpoint and subscription key.")
#     print("\nSet the COMPUTER_VISION_SUBSCRIPTION_KEY environment variable, such as \"1234567890abcdef1234567890abcdef\".\n")
#     missing_env = True
# 
# if missing_env:
#     print("**Restart your shell or IDE for changes to take effect.**")
#     sys.exit()

# Set API key.
subscription_key = '390b0e8c9f8b43d9a21e896e74ae1c7b'
# Set endpoint.
endpoint = 'https://aien08cv01.cognitiveservices.azure.com/'

text_recognition_url = endpoint + "/vision/v3.0/read/analyze"

# Set image_url to the URL of an image that you want to recognize.
image_url = "https://www.learnalberta.ca/content/eslapb/images/gr5_lev3_lrg.jpg"

headers = {'Ocp-Apim-Subscription-Key': subscription_key}
data = {'url': image_url}
response = requests.post(
    text_recognition_url, headers=headers, json=data)
response.raise_for_status()

# Extracting text requires two API calls: One call to submit the
# image for processing, the other to retrieve the text found in the image.

# Holds the URI used to retrieve the recognized text.
operation_url = response.headers["Operation-Location"]

# The recognized text isn't immediately available, so poll to wait for completion.
analysis = {}
poll = True
while (poll):
    response_final = requests.get(
        response.headers["Operation-Location"], headers=headers)
    analysis = response_final.json()
    
    print(json.dumps(analysis, indent=4))

    time.sleep(1)
    if ("analyzeResult" in analysis):
        poll = False
    if ("status" in analysis and analysis['status'] == 'failed'):
        poll = False

polygons = []
if ("analyzeResult" in analysis):
    # Extract the recognized text, with bounding boxes.
    polygons = [(line["boundingBox"], line["text"])
                for line in analysis["analyzeResult"]["readResults"][0]["lines"]]

# Display the image and overlay it with the extracted text.
image = Image.open(BytesIO(requests.get(image_url).content))
ax = plt.imshow(image)
for polygon in polygons:
    vertices = [(polygon[0][i], polygon[0][i+1])
                for i in range(0, len(polygon[0]), 2)]
    text = polygon[1]
    patch = Polygon(vertices, closed=True, fill=False, linewidth=2, color='y')
    ax.axes.add_patch(patch)
    plt.text(vertices[0][0], vertices[0][1], text, fontsize=20, va="top")
plt.show()
# Out:
# {
#     "status": "succeeded",
#     "createdDateTime": "2020-08-03T09:29:17Z",
#     "lastUpdatedDateTime": "2020-08-03T09:29:18Z",
#     "analyzeResult": {
#         "version": "3.0.0",
#         "readResults": [
#             {
#                 "page": 1,
#                 "angle": 0.4024,
#                 "width": 630,
#                 "height": 630,
#                 "unit": "pixel",
#                 "lines": [
#                     {
#                         "boundingBox": [
#                             83,
#                             4,
#                             272,
#                             8,
#                             272,
#                             42,
#                             83,
#                             41
#                         ],
#                         "text": "Ire of the",
#                         "words": [
#                             {
#                                 "boundingBox": [
#                                     131,
#                                     7,
#                                     187,
#                                     9,
#                                     187,
#                                     42,
#                                     132,
#                                     42
#                                 ],
#                                 "text": "Ire",
#                                 "confidence": 0.559
#                             },
#                             {
#                                 "boundingBox": [
#                                     194,
#                                     10,
#                                     230,
#                                     11,
#                                     230,
#                                     42,
#                                     194,
#                                     42
#                                 ],
#                                 "text": "of",
#                                 "confidence": 0.981
#                             },
#                             {
#                                 "boundingBox": [
#                                     238,
#                                     11,
#                                     271,
#                                     11,
#                                     271,
#                                     42,
#                                     237,
#                                     42
#                                 ],
#                                 "text": "the",
#                                 "confidence": 0.986
#                             }
#                         ]
#                     },
#                     {
#                         "boundingBox": [
#                             367,
#                             21,
#                             424,
#                             18,
#                             425,
#                             42,
#                             369,
#                             45
#                         ],
#                         "text": "people",
#                         "words": [
#                             {
#                                 "boundingBox": [
#                                     371,
#                                     21,
#                                     423,
#                                     18,
#                                     424,
#                                     42,
#                                     373,
#                                     45
#                                 ],
#                                 "text": "people",
#                                 "confidence": 0.652
#                             }
#                         ]
#                     },
#                     {
#                         "boundingBox": [
#                             80,
#                             68,
#                             201,
#                             69,
#                             201,
#                             100,
#                             80,
#                             99
#                         ],
#                         "text": "I came to",
#                         "words": [
#                             {
#                                 "boundingBox": [
#                                     80,
#                                     69,
#                                     101,
#                                     69,
#                                     101,
#                                     100,
#                                     81,
#                                     100
#                                 ],
#                                 "text": "I",
#                                 "confidence": 0.986
#                             },
#                             {
#                                 "boundingBox": [
#                                     107,
#                                     69,
#                                     169,
#                                     70,
#                                     169,
#                                     100,
#                                     107,
#                                     100
#                                 ],
#                                 "text": "came",
#                                 "confidence": 0.559
#                             },
#                             {
#                                 "boundingBox": [
#                                     175,
#                                     70,
#                                     200,
#                                     70,
#                                     200,
#                                     100,
#                                     176,
#                                     100
#                                 ],
#                                 "text": "to",
#                                 "confidence": 0.986
#                             }
#                         ]
#                     },
#                     {
#                         "boundingBox": [
#                             377,
#                             77,
#                             475,
#                             77,
#                             475,
#                             100,
#                             377,
#                             100
#                         ],
#                         "text": "was always",
#                         "words": [
#                             {
#                                 "boundingBox": [
#                                     379,
#                                     78,
#                                     414,
#                                     78,
#                                     414,
#                                     101,
#                                     379,
#                                     101
#                                 ],
#                                 "text": "was",
#                                 "confidence": 0.957
#                             },
#                             {
#                                 "boundingBox": [
#                                     419,
#                                     78,
#                                     474,
#                                     77,
#                                     475,
#                                     101,
#                                     419,
#                                     101
#                                 ],
#                                 "text": "always",
#                                 "confidence": 0.98
#                             }
#                         ]
#                     },
#                     {
#                         "boundingBox": [
#                             77,
#                             130,
#                             352,
#                             130,
#                             352,
#                             157,
#                             77,
#                             158
#                         ],
#                         "text": "Spek English and French In",
#                         "words": [
#                             {
#                                 "boundingBox": [
#                                     77,
#                                     131,
#                                     126,
#                                     131,
#                                     126,
#                                     158,
#                                     78,
#                                     158
#                                 ],
#                                 "text": "Spek",
#                                 "confidence": 0.825
#                             },
#                             {
#                                 "boundingBox": [
#                                     131,
#                                     131,
#                                     194,
#                                     131,
#                                     194,
#                                     158,
#                                     132,
#                                     158
#                                 ],
#                                 "text": "English",
#                                 "confidence": 0.943
#                             },
#                             {
#                                 "boundingBox": [
#                                     199,
#                                     131,
#                                     244,
#                                     131,
#                                     245,
#                                     158,
#                                     200,
#                                     158
#                                 ],
#                                 "text": "and",
#                                 "confidence": 0.974
#                             },
#                             {
#                                 "boundingBox": [
#                                     250,
#                                     131,
#                                     318,
#                                     131,
#                                     318,
#                                     158,
#                                     250,
#                                     158
#                                 ],
#                                 "text": "French",
#                                 "confidence": 0.559
#                             },
#                             {
#                                 "boundingBox": [
#                                     325,
#                                     131,
#                                     352,
#                                     131,
#                                     352,
#                                     157,
#                                     325,
#                                     157
#                                 ],
#                                 "text": "In",
#                                 "confidence": 0.943
#                             }
#                         ]
#                     },
#                     {
#                         "boundingBox": [
#                             433,
#                             136,
#                             475,
#                             136,
#                             475,
#                             155,
#                             433,
#                             159
#                         ],
#                         "text": "was",
#                         "words": [
#                             {
#                                 "boundingBox": [
#                                     446,
#                                     136,
#                                     474,
#                                     136,
#                                     475,
#                                     156,
#                                     448,
#                                     157
#                                 ],
#                                 "text": "was",
#                                 "confidence": 0.69
#                             }
#                         ]
#                     },
#                     {
#                         "boundingBox": [
#                             79,
#                             188,
#                             466,
#                             187,
#                             466,
#                             215,
#                             79,
#                             216
#                         ],
#                         "text": "not always speak english or French it was",
#                         "words": [
#                             {
#                                 "boundingBox": [
#                                     80,
#                                     190,
#                                     116,
#                                     189,
#                                     116,
#                                     216,
#                                     80,
#                                     216
#                                 ],
#                                 "text": "not",
#                                 "confidence": 0.978
#                             },
#                             {
#                                 "boundingBox": [
#                                     121,
#                                     189,
#                                     184,
#                                     188,
#                                     184,
#                                     216,
#                                     122,
#                                     216
#                                 ],
#                                 "text": "always",
#                                 "confidence": 0.889
#                             },
#                             {
#                                 "boundingBox": [
#                                     189,
#                                     188,
#                                     240,
#                                     188,
#                                     239,
#                                     216,
#                                     189,
#                                     216
#                                 ],
#                                 "text": "speak",
#                                 "confidence": 0.734
#                             },
#                             {
#                                 "boundingBox": [
#                                     245,
#                                     188,
#                                     307,
#                                     187,
#                                     307,
#                                     216,
#                                     245,
#                                     216
#                                 ],
#                                 "text": "english",
#                                 "confidence": 0.825
#                             },
#                             {
#                                 "boundingBox": [
#                                     313,
#                                     188,
#                                     333,
#                                     188,
#                                     333,
#                                     216,
#                                     312,
#                                     216
#                                 ],
#                                 "text": "or",
#                                 "confidence": 0.984
#                             },
#                             {
#                                 "boundingBox": [
#                                     339,
#                                     188,
#                                     393,
#                                     188,
#                                     392,
#                                     215,
#                                     338,
#                                     216
#                                 ],
#                                 "text": "French",
#                                 "confidence": 0.928
#                             },
#                             {
#                                 "boundingBox": [
#                                     398,
#                                     188,
#                                     429,
#                                     188,
#                                     428,
#                                     215,
#                                     397,
#                                     215
#                                 ],
#                                 "text": "it",
#                                 "confidence": 0.986
#                             },
#                             {
#                                 "boundingBox": [
#                                     434,
#                                     188,
#                                     466,
#                                     189,
#                                     465,
#                                     215,
#                                     433,
#                                     215
#                                 ],
#                                 "text": "was",
#                                 "confidence": 0.984
#                             }
#                         ]
#                     },
#                     {
#                         "boundingBox": [
#                             77,
#                             241,
#                             433,
#                             244,
#                             433,
#                             273,
#                             77,
#                             271
#                         ],
#                         "text": "different . There are no pets allowed in",
#                         "words": [
#                             {
#                                 "boundingBox": [
#                                     79,
#                                     242,
#                                     140,
#                                     243,
#                                     140,
#                                     272,
#                                     79,
#                                     272
#                                 ],
#                                 "text": "different",
#                                 "confidence": 0.639
#                             },
#                             {
#                                 "boundingBox": [
#                                     146,
#                                     243,
#                                     164,
#                                     243,
#                                     164,
#                                     273,
#                                     146,
#                                     272
#                                 ],
#                                 "text": ".",
#                                 "confidence": 0.726
#                             },
#                             {
#                                 "boundingBox": [
#                                     169,
#                                     243,
#                                     222,
#                                     244,
#                                     222,
#                                     273,
#                                     169,
#                                     273
#                                 ],
#                                 "text": "There",
#                                 "confidence": 0.979
#                             },
#                             {
#                                 "boundingBox": [
#                                     228,
#                                     244,
#                                     262,
#                                     244,
#                                     261,
#                                     273,
#                                     228,
#                                     273
#                                 ],
#                                 "text": "are",
#                                 "confidence": 0.98
#                             },
#                             {
#                                 "boundingBox": [
#                                     267,
#                                     244,
#                                     287,
#                                     244,
#                                     287,
#                                     273,
#                                     267,
#                                     273
#                                 ],
#                                 "text": "no",
#                                 "confidence": 0.985
#                             },
#                             {
#                                 "boundingBox": [
#                                     293,
#                                     244,
#                                     330,
#                                     245,
#                                     330,
#                                     273,
#                                     292,
#                                     273
#                                 ],
#                                 "text": "pets",
#                                 "confidence": 0.974
#                             },
#                             {
#                                 "boundingBox": [
#                                     336,
#                                     245,
#                                     393,
#                                     245,
#                                     392,
#                                     273,
#                                     335,
#                                     273
#                                 ],
#                                 "text": "allowed",
#                                 "confidence": 0.973
#                             },
#                             {
#                                 "boundingBox": [
#                                     399,
#                                     245,
#                                     432,
#                                     245,
#                                     431,
#                                     273,
#                                     398,
#                                     273
#                                 ],
#                                 "text": "in",
#                                 "confidence": 0.981
#                             }
#                         ]
#                     },
#                     {
#                         "boundingBox": [
#                             510,
#                             244,
#                             562,
#                             247,
#                             562,
#                             272,
#                             510,
#                             271
#                         ],
#                         "text": "But",
#                         "words": [
#                             {
#                                 "boundingBox": [
#                                     519,
#                                     244,
#                                     562,
#                                     246,
#                                     561,
#                                     273,
#                                     518,
#                                     271
#                                 ],
#                                 "text": "But",
#                                 "confidence": 0.986
#                             }
#                         ]
#                     },
#                     {
#                         "boundingBox": [
#                             79,
#                             297,
#                             502,
#                             302,
#                             502,
#                             333,
#                             79,
#                             330
#                         ],
#                         "text": "heve has pets . There is no show , everything is",
#                         "words": [
#                             {
#                                 "boundingBox": [
#                                     79,
#                                     298,
#                                     121,
#                                     299,
#                                     121,
#                                     331,
#                                     79,
#                                     331
#                                 ],
#                                 "text": "heve",
#                                 "confidence": 0.786
#                             },
#                             {
#                                 "boundingBox": [
#                                     128,
#                                     299,
#                                     161,
#                                     300,
#                                     161,
#                                     330,
#                                     127,
#                                     330
#                                 ],
#                                 "text": "has",
#                                 "confidence": 0.998
#                             },
#                             {
#                                 "boundingBox": [
#                                     167,
#                                     300,
#                                     194,
#                                     300,
#                                     194,
#                                     330,
#                                     167,
#                                     330
#                                 ],
#                                 "text": "pets",
#                                 "confidence": 0.936
#                             },
#                             {
#                                 "boundingBox": [
#                                     200,
#                                     300,
#                                     218,
#                                     301,
#                                     218,
#                                     330,
#                                     200,
#                                     330
#                                 ],
#                                 "text": ".",
#                                 "confidence": 0.938
#                             },
#                             {
#                                 "boundingBox": [
#                                     224,
#                                     301,
#                                     266,
#                                     302,
#                                     266,
#                                     330,
#                                     224,
#                                     330
#                                 ],
#                                 "text": "There",
#                                 "confidence": 1
#                             },
#                             {
#                                 "boundingBox": [
#                                     273,
#                                     302,
#                                     306,
#                                     302,
#                                     306,
#                                     330,
#                                     273,
#                                     330
#                                 ],
#                                 "text": "is",
#                                 "confidence": 1
#                             },
#                             {
#                                 "boundingBox": [
#                                     312,
#                                     303,
#                                     334,
#                                     303,
#                                     335,
#                                     330,
#                                     313,
#                                     330
#                                 ],
#                                 "text": "no",
#                                 "confidence": 0.724
#                             },
#                             {
#                                 "boundingBox": [
#                                     341,
#                                     303,
#                                     370,
#                                     303,
#                                     370,
#                                     331,
#                                     341,
#                                     330
#                                 ],
#                                 "text": "show",
#                                 "confidence": 0.712
#                             },
#                             {
#                                 "boundingBox": [
#                                     376,
#                                     304,
#                                     383,
#                                     304,
#                                     383,
#                                     331,
#                                     376,
#                                     331
#                                 ],
#                                 "text": ",",
#                                 "confidence": 0.766
#                             },
#                             {
#                                 "boundingBox": [
#                                     389,
#                                     304,
#                                     469,
#                                     305,
#                                     469,
#                                     333,
#                                     390,
#                                     331
#                                 ],
#                                 "text": "everything",
#                                 "confidence": 1
#                             },
#                             {
#                                 "boundingBox": [
#                                     475,
#                                     305,
#                                     502,
#                                     305,
#                                     502,
#                                     333,
#                                     476,
#                                     333
#                                 ],
#                                 "text": "is",
#                                 "confidence": 1
#                             }
#                         ]
#                     },
#                     {
#                         "boundingBox": [
#                             77,
#                             360,
#                             547,
#                             357,
#                             547,
#                             386,
#                             77,
#                             389
#                         ],
#                         "text": "green but here snow and white . Heve has Halloween",
#                         "words": [
#                             {
#                                 "boundingBox": [
#                                     79,
#                                     361,
#                                     129,
#                                     360,
#                                     129,
#                                     389,
#                                     78,
#                                     390
#                                 ],
#                                 "text": "green",
#                                 "confidence": 0.65
#                             },
#                             {
#                                 "boundingBox": [
#                                     135,
#                                     360,
#                                     167,
#                                     360,
#                                     167,
#                                     388,
#                                     134,
#                                     389
#                                 ],
#                                 "text": "but",
#                                 "confidence": 0.981
#                             },
#                             {
#                                 "boundingBox": [
#                                     173,
#                                     360,
#                                     210,
#                                     359,
#                                     210,
#                                     388,
#                                     172,
#                                     388
#                                 ],
#                                 "text": "here",
#                                 "confidence": 0.75
#                             },
#                             {
#                                 "boundingBox": [
#                                     216,
#                                     359,
#                                     263,
#                                     359,
#                                     263,
#                                     387,
#                                     216,
#                                     388
#                                 ],
#                                 "text": "snow",
#                                 "confidence": 0.977
#                             },
#                             {
#                                 "boundingBox": [
#                                     269,
#                                     359,
#                                     312,
#                                     358,
#                                     312,
#                                     387,
#                                     268,
#                                     387
#                                 ],
#                                 "text": "and",
#                                 "confidence": 0.986
#                             },
#                             {
#                                 "boundingBox": [
#                                     318,
#                                     358,
#                                     350,
#                                     358,
#                                     350,
#                                     387,
#                                     318,
#                                     387
#                                 ],
#                                 "text": "white",
#                                 "confidence": 0.979
#                             },
#                             {
#                                 "boundingBox": [
#                                     355,
#                                     358,
#                                     374,
#                                     358,
#                                     374,
#                                     386,
#                                     355,
#                                     387
#                                 ],
#                                 "text": ".",
#                                 "confidence": 0.786
#                             },
#                             {
#                                 "boundingBox": [
#                                     380,
#                                     358,
#                                     416,
#                                     358,
#                                     416,
#                                     386,
#                                     380,
#                                     386
#                                 ],
#                                 "text": "Heve",
#                                 "confidence": 0.562
#                             },
#                             {
#                                 "boundingBox": [
#                                     421,
#                                     358,
#                                     459,
#                                     357,
#                                     459,
#                                     386,
#                                     421,
#                                     386
#                                 ],
#                                 "text": "has",
#                                 "confidence": 0.801
#                             },
#                             {
#                                 "boundingBox": [
#                                     465,
#                                     357,
#                                     547,
#                                     357,
#                                     548,
#                                     387,
#                                     465,
#                                     386
#                                 ],
#                                 "text": "Halloween",
#                                 "confidence": 0.953
#                             }
#                         ]
#                     },
#                     {
#                         "boundingBox": [
#                             79,
#                             414,
#                             289,
#                             413,
#                             289,
#                             445,
#                             79,
#                             446
#                         ],
#                         "text": "and clivistines but in",
#                         "words": [
#                             {
#                                 "boundingBox": [
#                                     79,
#                                     415,
#                                     118,
#                                     415,
#                                     117,
#                                     445,
#                                     79,
#                                     446
#                                 ],
#                                 "text": "and",
#                                 "confidence": 0.985
#                             },
#                             {
#                                 "boundingBox": [
#                                     124,
#                                     415,
#                                     214,
#                                     414,
#                                     214,
#                                     446,
#                                     123,
#                                     445
#                                 ],
#                                 "text": "clivistines",
#                                 "confidence": 0.835
#                             },
#                             {
#                                 "boundingBox": [
#                                     220,
#                                     414,
#                                     249,
#                                     414,
#                                     249,
#                                     446,
#                                     220,
#                                     446
#                                 ],
#                                 "text": "but",
#                                 "confidence": 0.986
#                             },
#                             {
#                                 "boundingBox": [
#                                     255,
#                                     414,
#                                     289,
#                                     414,
#                                     289,
#                                     446,
#                                     255,
#                                     446
#                                 ],
#                                 "text": "in",
#                                 "confidence": 0.981
#                             }
#                         ]
#                     },
#                     {
#                         "boundingBox": [
#                             333,
#                             413,
#                             537,
#                             415,
#                             536,
#                             443,
#                             333,
#                             440
#                         ],
#                         "text": ". has no Halloween",
#                         "words": [
#                             {
#                                 "boundingBox": [
#                                     356,
#                                     414,
#                                     371,
#                                     414,
#                                     371,
#                                     441,
#                                     356,
#                                     441
#                                 ],
#                                 "text": ".",
#                                 "confidence": 0.787
#                             },
#                             {
#                                 "boundingBox": [
#                                     376,
#                                     414,
#                                     413,
#                                     414,
#                                     412,
#                                     442,
#                                     376,
#                                     442
#                                 ],
#                                 "text": "has",
#                                 "confidence": 0.588
#                             },
#                             {
#                                 "boundingBox": [
#                                     418,
#                                     414,
#                                     447,
#                                     414,
#                                     447,
#                                     443,
#                                     418,
#                                     442
#                                 ],
#                                 "text": "no",
#                                 "confidence": 0.975
#                             },
#                             {
#                                 "boundingBox": [
#                                     452,
#                                     414,
#                                     537,
#                                     417,
#                                     536,
#                                     444,
#                                     452,
#                                     443
#                                 ],
#                                 "text": "Halloween",
#                                 "confidence": 0.861
#                             }
#                         ]
#                     },
#                     {
#                         "boundingBox": [
#                             75,
#                             472,
#                             290,
#                             471,
#                             290,
#                             502,
#                             75,
#                             502
#                         ],
#                         "text": "and elberstinas . In",
#                         "words": [
#                             {
#                                 "boundingBox": [
#                                     77,
#                                     472,
#                                     126,
#                                     472,
#                                     125,
#                                     503,
#                                     76,
#                                     503
#                                 ],
#                                 "text": "and",
#                                 "confidence": 0.985
#                             },
#                             {
#                                 "boundingBox": [
#                                     132,
#                                     472,
#                                     224,
#                                     472,
#                                     224,
#                                     503,
#                                     131,
#                                     503
#                                 ],
#                                 "text": "elberstinas",
#                                 "confidence": 0.559
#                             },
#                             {
#                                 "boundingBox": [
#                                     230,
#                                     472,
#                                     245,
#                                     472,
#                                     245,
#                                     503,
#                                     231,
#                                     503
#                                 ],
#                                 "text": ".",
#                                 "confidence": 0.747
#                             },
#                             {
#                                 "boundingBox": [
#                                     251,
#                                     472,
#                                     290,
#                                     472,
#                                     291,
#                                     503,
#                                     251,
#                                     503
#                                 ],
#                                 "text": "In",
#                                 "confidence": 0.979
#                             }
#                         ]
#                     },
#                     {
#                         "boundingBox": [
#                             358,
#                             470,
#                             475,
#                             470,
#                             476,
#                             500,
#                             358,
#                             500
#                         ],
#                         "text": "I like the",
#                         "words": [
#                             {
#                                 "boundingBox": [
#                                     363,
#                                     471,
#                                     381,
#                                     471,
#                                     381,
#                                     501,
#                                     363,
#                                     501
#                                 ],
#                                 "text": "I",
#                                 "confidence": 0.986
#                             },
#                             {
#                                 "boundingBox": [
#                                     387,
#                                     471,
#                                     429,
#                                     471,
#                                     429,
#                                     501,
#                                     387,
#                                     501
#                                 ],
#                                 "text": "like",
#                                 "confidence": 0.985
#                             },
#                             {
#                                 "boundingBox": [
#                                     435,
#                                     471,
#                                     476,
#                                     471,
#                                     476,
#                                     500,
#                                     436,
#                                     501
#                                 ],
#                                 "text": "the",
#                                 "confidence": 0.981
#                             }
#                         ]
#                     },
#                     {
#                         "boundingBox": [
#                             80,
#                             531,
#                             195,
#                             532,
#                             195,
#                             558,
#                             80,
#                             557
#                         ],
#                         "text": "rules but in",
#                         "words": [
#                             {
#                                 "boundingBox": [
#                                     80,
#                                     531,
#                                     129,
#                                     532,
#                                     129,
#                                     558,
#                                     81,
#                                     558
#                                 ],
#                                 "text": "rules",
#                                 "confidence": 0.652
#                             },
#                             {
#                                 "boundingBox": [
#                                     134,
#                                     532,
#                                     164,
#                                     532,
#                                     164,
#                                     559,
#                                     134,
#                                     558
#                                 ],
#                                 "text": "but",
#                                 "confidence": 0.986
#                             },
#                             {
#                                 "boundingBox": [
#                                     170,
#                                     532,
#                                     195,
#                                     532,
#                                     194,
#                                     559,
#                                     169,
#                                     559
#                                 ],
#                                 "text": "in",
#                                 "confidence": 0.986
#                             }
#                         ]
#                     },
#                     {
#                         "boundingBox": [
#                             288,
#                             526,
#                             531,
#                             529,
#                             531,
#                             560,
#                             287,
#                             557
#                         ],
#                         "text": "there are too much rules .",
#                         "words": [
#                             {
#                                 "boundingBox": [
#                                     288,
#                                     527,
#                                     327,
#                                     527,
#                                     327,
#                                     558,
#                                     288,
#                                     558
#                                 ],
#                                 "text": "there",
#                                 "confidence": 0.979
#                             },
#                             {
#                                 "boundingBox": [
#                                     333,
#                                     527,
#                                     372,
#                                     528,
#                                     372,
#                                     558,
#                                     333,
#                                     558
#                                 ],
#                                 "text": "are",
#                                 "confidence": 0.939
#                             },
#                             {
#                                 "boundingBox": [
#                                     378,
#                                     528,
#                                     421,
#                                     528,
#                                     421,
#                                     559,
#                                     378,
#                                     558
#                                 ],
#                                 "text": "too",
#                                 "confidence": 0.981
#                             },
#                             {
#                                 "boundingBox": [
#                                     427,
#                                     528,
#                                     474,
#                                     529,
#                                     474,
#                                     560,
#                                     427,
#                                     559
#                                 ],
#                                 "text": "much",
#                                 "confidence": 0.955
#                             },
#                             {
#                                 "boundingBox": [
#                                     481,
#                                     529,
#                                     511,
#                                     530,
#                                     511,
#                                     561,
#                                     480,
#                                     560
#                                 ],
#                                 "text": "rules",
#                                 "confidence": 0.885
#                             },
#                             {
#                                 "boundingBox": [
#                                     517,
#                                     530,
#                                     532,
#                                     530,
#                                     531,
#                                     561,
#                                     517,
#                                     561
#                                 ],
#                                 "text": ".",
#                                 "confidence": 0.739
#                             }
#                         ]
#                     },
#                     {
#                         "boundingBox": [
#                             82,
#                             585,
#                             411,
#                             588,
#                             411,
#                             618,
#                             82,
#                             614
#                         ],
#                         "text": "My house was small but heve big.",
#                         "words": [
#                             {
#                                 "boundingBox": [
#                                     87,
#                                     585,
#                                     113,
#                                     586,
#                                     113,
#                                     615,
#                                     86,
#                                     614
#                                 ],
#                                 "text": "My",
#                                 "confidence": 0.981
#                             },
#                             {
#                                 "boundingBox": [
#                                     119,
#                                     586,
#                                     171,
#                                     588,
#                                     170,
#                                     616,
#                                     119,
#                                     615
#                                 ],
#                                 "text": "house",
#                                 "confidence": 0.95
#                             },
#                             {
#                                 "boundingBox": [
#                                     176,
#                                     588,
#                                     214,
#                                     589,
#                                     214,
#                                     617,
#                                     176,
#                                     616
#                                 ],
#                                 "text": "was",
#                                 "confidence": 0.559
#                             },
#                             {
#                                 "boundingBox": [
#                                     220,
#                                     589,
#                                     277,
#                                     589,
#                                     277,
#                                     617,
#                                     220,
#                                     617
#                                 ],
#                                 "text": "small",
#                                 "confidence": 0.825
#                             },
#                             {
#                                 "boundingBox": [
#                                     283,
#                                     589,
#                                     321,
#                                     589,
#                                     321,
#                                     618,
#                                     283,
#                                     617
#                                 ],
#                                 "text": "but",
#                                 "confidence": 0.98
#                             },
#                             {
#                                 "boundingBox": [
#                                     327,
#                                     589,
#                                     373,
#                                     589,
#                                     373,
#                                     618,
#                                     327,
#                                     618
#                                 ],
#                                 "text": "heve",
#                                 "confidence": 0.652
#                             },
#                             {
#                                 "boundingBox": [
#                                     379,
#                                     589,
#                                     411,
#                                     589,
#                                     411,
#                                     618,
#                                     379,
#                                     618
#                                 ],
#                                 "text": "big.",
#                                 "confidence": 0.652
#                             }
#                         ]
#                     }
#                 ]
#             }
#         ]
#     }
# }

# %% [markdown]
# # 手寫文字辨識服務操作

# %%
from azure.cognitiveservices.vision.computervision import ComputerVisionClient
from azure.cognitiveservices.vision.computervision.models import TextOperationStatusCodes
from msrest.authentication import CognitiveServicesCredentials
import time

# Set API key.
subscription_key = '390b0e8c9f8b43d9a21e896e74ae1c7b'
# Set endpoint.
endpoint = 'https://aien08cv01.cognitiveservices.azure.com/'
# Call API
computervision_client = ComputerVisionClient(endpoint, CognitiveServicesCredentials(subscription_key))

'''
Batch Read File, recognize printed text - remote
This example will extract printed text in an image, then print results, line by line.
This API call can also recognize handwriting (not shown).
'''
print("===== Batch Read File - remote =====")
# Get an image with printed handwritten
remote_image_printed_text_url = " https://westus2.api.cognitive.microsoft.com/vision/v3.1-preview.1/read/analyzeResults/ba57e933-ba54-4b09-8f2d-c7ed27e10bec"

# Call API with URL and raw response (allows you to get the operation location)
recognize_printed_results = computervision_client.batch_read_file(remote_image_printed_text_url,  raw=True)

# Get the operation location (URL with an ID at the end) from the response
operation_location_remote = recognize_printed_results.headers["Operation-Location"]
# Grab the ID from the URL
operation_id = operation_location_remote.split("/")[-1]

# Call the "GET" API and wait for it to retrieve the results 
while True:
    get_printed_text_results = computervision_client.get_read_operation_result(operation_id)
    if get_printed_text_results.status not in ['NotStarted', 'Running']:
        break
    time.sleep(1)

# Print the detected text, line by line
if get_printed_text_results.status == TextOperationStatusCodes.succeeded:
    for text_result in get_printed_text_results.recognition_results:
        for line in text_result.lines:
            print(line.text)
            print(line.bounding_box)
print()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-32-9d61f302f6fb> in <module>
#       1 from azure.cognitiveservices.vision.computervision import ComputerVisionClient
# ----> 2 from azure.cognitiveservices.vision.computervision.models import TextOperationStatusCodes
#       3 from msrest.authentication import CognitiveServicesCredentials
#       4 import time
#       5
#
# ImportError: cannot import name 'TextOperationStatusCodes' from 'azure.cognitiveservices.vision.computervision.models' (C:\Users\Student\.conda\envs\Azure\lib\site-packages\azure\cognitiveservices\vision\computervision\models\__init__.py)

# %%
import os
import sys
import requests
# If you are using a Jupyter notebook, uncomment the following line.
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from PIL import Image
from io import BytesIO

# Add your Computer Vision subscription key and endpoint to your environment variables.
# if 'COMPUTER_VISION_SUBSCRIPTION_KEY' in os.environ:
#     subscription_key = os.environ['COMPUTER_VISION_SUBSCRIPTION_KEY']
# else:
#     print("\nSet the COMPUTER_VISION_SUBSCRIPTION_KEY environment variable.\n**Restart your shell or IDE for changes to take effect.**")
#     sys.exit()

# if 'COMPUTER_VISION_ENDPOINT' in os.environ:
#     endpoint = os.environ['COMPUTER_VISION_ENDPOINT']

# Set image_url to the URL of an image that you want to analyze.
image_url = "https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/" + \
    "Atomist_quote_from_Democritus.png/338px-Atomist_quote_from_Democritus.png"

# Set API key.
subscription_key = '390b0e8c9f8b43d9a21e896e74ae1c7b'
# Set endpoint.
endpoint = 'https://aien08cv01.cognitiveservices.azure.com/'
ocr_url = endpoint + "vision/v3.0/ocr"

headers = {'Ocp-Apim-Subscription-Key': subscription_key}
params = {'language': 'unk', 'detectOrientation': 'true'}
data = {'url': image_url}
response = requests.post(ocr_url, headers=headers, params=params, json=data)
response.raise_for_status()

analysis = response.json()

# Extract the word bounding boxes and text.
line_infos = [region["lines"] for region in analysis["regions"]]
word_infos = []
for line in line_infos:
    for word_metadata in line:
        for word_info in word_metadata["words"]:
            word_infos.append(word_info)
word_infos

# Display the image and overlay it with the extracted text.
plt.figure(figsize=(5, 5))
image = Image.open(BytesIO(requests.get(image_url).content))
ax = plt.imshow(image, alpha=0.5)
for word in word_infos:
    bbox = [int(num) for num in word["boundingBox"].split(",")]
    text = word["text"]
    origin = (bbox[0], bbox[1])
    patch = Rectangle(origin, bbox[2], bbox[3],
                      fill=False, linewidth=2, color='y')
    ax.axes.add_patch(patch)
    plt.text(origin[0], origin[1], text, fontsize=20, weight="bold", va="top")
plt.show()
plt.axis("off")
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
import os
import sys
import requests
# If you are using a Jupyter notebook, uncomment the following line.
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from PIL import Image
from io import BytesIO

import http.client, urllib.request, urllib.parse, urllib.error, base64

headers = {
    # Request headers
    'Content-Type': 'application/json',
    'Ocp-Apim-Subscription-Key': '{subscription key}',
}

params = urllib.parse.urlencode({
    # Request parameters
    'language': '{string}',
})

try:
#     conn = http.client.HTTPSConnection('westcentralus.api.cognitive.microsoft.com')
    conn = http.client.HTTPSConnection('https://westus2.api.cognitive.microsoft.com/vision/v3.1-preview.1/read/analyzeResults/ba57e933-ba54-4b09-8f2d-c7ed27e10bec')
    conn.request("POST", "/vision/v3.0/read/analyze?%s" % params, "{body}", headers)
    response = conn.getresponse()
    data = response.read()
    print(data)
    conn.close()
except Exception as e:
    print("[Errno {0}] {1}".format(e.errno, e.strerror))

# Set image_url to the URL of an image that you want to analyze.
image_url = "https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/" + \
    "Atomist_quote_from_Democritus.png/338px-Atomist_quote_from_Democritus.png"

# # Set API key.
# subscription_key = '390b0e8c9f8b43d9a21e896e74ae1c7b'
# # Set endpoint.
# endpoint = 'https://aien08cv01.cognitiveservices.azure.com/'
# ocr_url = endpoint + "vision/v3.0/ocr"

# headers = {'Ocp-Apim-Subscription-Key': subscription_key}
# params = {'language': 'unk', 'detectOrientation': 'true'}
# data = {'url': image_url}
# response = requests.post(ocr_url, headers=headers, params=params, json=data)
# response.raise_for_status()

analysis = response.json()

# Extract the word bounding boxes and text.
line_infos = [region["lines"] for region in analysis["regions"]]
word_infos = []
for line in line_infos:
    for word_metadata in line:
        for word_info in word_metadata["words"]:
            word_infos.append(word_info)
word_infos

# Display the image and overlay it with the extracted text.
plt.figure(figsize=(5, 5))
image = Image.open(BytesIO(requests.get(image_url).content))
ax = plt.imshow(image, alpha=0.5)
for word in word_infos:
    bbox = [int(num) for num in word["boundingBox"].split(",")]
    text = word["text"]
    origin = (bbox[0], bbox[1])
    patch = Rectangle(origin, bbox[2], bbox[3],
                      fill=False, linewidth=2, color='y')
    ax.axes.add_patch(patch)
    plt.text(origin[0], origin[1], text, fontsize=20, weight="bold", va="top")
plt.show()
plt.axis("off")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\.conda\envs\Azure\lib\http\client.py in _get_hostport(self, host, port)
#     886                 try:
# --> 887                     port = int(host[i+1:])
#     888                 except ValueError:
#
# ValueError: invalid literal for int() with base 10: '//westus2.api.cognitive.microsoft.com/vision/v3.1-preview.1/read/analyzeResults/ba57e933-ba54-4b09-8f2d-c7ed27e10bec'
#
# During handling of the above exception, another exception occurred:
#
# InvalidURL                                Traceback (most recent call last)
# <ipython-input-34-7321c059e2be> in <module>
#      25 #     conn = http.client.HTTPSConnection('westcentralus.api.cognitive.microsoft.com')
# ---> 26     conn = http.client.HTTPSConnection('https://westus2.api.cognitive.microsoft.com/vision/v3.1-preview.1/read/analyzeResults/ba57e933-ba54-4b09-8f2d-c7ed27e10bec')
#      27     conn.request("POST", "/vision/v3.0/read/analyze?%s" % params, "{body}", headers)
#
# ~\.conda\envs\Azure\lib\http\client.py in __init__(self, host, port, key_file, cert_file, timeout, source_address, context, check_hostname, blocksize)
#    1380                                                   source_address,
# -> 1381                                                   blocksize=blocksize)
#    1382             if (key_file is not None or cert_file is not None or
#
# ~\.conda\envs\Azure\lib\http\client.py in __init__(self, host, port, timeout, source_address, blocksize)
#     850
# --> 851         (self.host, self.port) = self._get_hostport(host, port)
#     852
#
# ~\.conda\envs\Azure\lib\http\client.py in _get_hostport(self, host, port)
#     891                     else:
# --> 892                         raise InvalidURL("nonnumeric port: '%s'" % host[i+1:])
#     893                 host = host[:i]
#
# InvalidURL: nonnumeric port: '//westus2.api.cognitive.microsoft.com/vision/v3.1-preview.1/read/analyzeResults/ba57e933-ba54-4b09-8f2d-c7ed27e10bec'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-7321c059e2be> in <module>
#      31     conn.close()
#      32 except Exception as e:
# ---> 33     print("[Errno {0}] {1}".format(e.errno, e.strerror))
#      34
#      35 # Set image_url to the URL of an image that you want to analyze.
#
# AttributeError: 'InvalidURL' object has no attribute 'errno'

# %%
import http.client, urllib.request, urllib.parse, urllib.error, base64

headers = {
    # Request headers
    'Content-Type': 'application/json',
    'Ocp-Apim-Subscription-Key': '{390b0e8c9f8b43d9a21e896e74ae1c7b}',
}

params = urllib.parse.urlencode({
    # Request parameters
    'language': '{en}',
})

try:
    conn = http.client.HTTPSConnection('westus2.api.cognitive.microsoft.com')
    conn.request("POST", "/vision/v3.1-preview.1/read/analyze?%s" % params, "{body}", headers)
    response = conn.getresponse()
    data = response.read()
    print(data)
    conn.close()
except Exception as e:
    print("[Errno {0}] {1}".format(e.errno, e.strerror))

# %%
import http.client, urllib.request, urllib.parse, urllib.error, base64

headers = {
    # Request headers
    'Content-Type': 'application/json',
    'Ocp-Apim-Subscription-Key': '{subscription key}',
}

params = urllib.parse.urlencode({
    # Request parameters
    'language': '{string}',
})

try:
    conn = http.client.HTTPSConnection('westus.api.cognitive.microsoft.com')
    conn.request("POST", "/vision/v3.1-preview.1/read/analyze?%s" % params, "{body}", headers)
    response = conn.getresponse()
    data = response.read()
    print(data)
    conn.close()
except Exception as e:
    print("[Errno {0}] {1}".format(e.errno, e.strerror))
# Out:
# b'{"error":{"code":"401","message":"Access denied due to invalid subscription key or wrong API endpoint. Make sure to provide a valid key for an active subscription and use a correct regional API endpoint for your resource."}}'

# %% [markdown]
# # 成人內容偵測服務操作

# %%
from azure.cognitiveservices.vision.computervision import ComputerVisionClient
from msrest.authentication import CognitiveServicesCredentials
from IPython.display import Image
from IPython.core.display import HTML 

# Set API key.
subscription_key = '390b0e8c9f8b43d9a21e896e74ae1c7b'
# Set endpoint.
endpoint = 'https://aien08cv01.cognitiveservices.azure.com/'
# Call API
computervision_client = ComputerVisionClient(endpoint, CognitiveServicesCredentials(subscription_key))

remote_image_url = "https://movies.tw.campaign.yahoo.net/i/o/production/movies/December2018/63uLqxM1oKDm4AjiCqs9-800x1143.jpg"

'''
Detect Adult or Racy Content - remote
This example detects adult or racy content in a remote image, then prints the adult/racy score.
The score is ranged 0.0 - 1.0 with smaller numbers indicating negative results.
'''
print("===== Detect Adult or Racy Content - remote =====")
# Select the visual feature(s) you want
remote_image_features = ["adult"]
# Call API with URL and features
detect_adult_results_remote = computervision_client.analyze_image(remote_image_url, remote_image_features)

# Print results with adult/racy score
print("Analyzing remote image for adult or racy content ... ")
print("Is adult content: {} with confidence {:.2f}".format(detect_adult_results_remote.adult.is_adult_content, detect_adult_results_remote.adult.adult_score * 100))
print("Has racy content: {} with confidence {:.2f}".format(detect_adult_results_remote.adult.is_racy_content, detect_adult_results_remote.adult.racy_score * 100))
# Out:
# ===== Detect Adult or Racy Content - remote =====
# Analyzing remote image for adult or racy content ...
# Is adult content: False with confidence 1.99
# Has racy content: False with confidence 2.24
